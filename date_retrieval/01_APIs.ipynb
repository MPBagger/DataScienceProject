# %% [markdown]
# # APIs for data retrieval

# %% [markdown]
# An Application Programming Interface, commonly known as API, is a set of protocols, routines, and tools for building software applications. APIs allow different software systems to communicate with each other and exchange data in a standardized and efficient way.
#
# APIs for retrieving data enable developers to access and extract information from various sources such as databases, web services, or applications. These APIs often provide a structured and consistent way of accessing data, making it easier for developers to consume and use the data in their applications.
#
# APIs for retrieving data can be used for a variety of purposes, such as gathering information for business intelligence, analyzing user behavior, or integrating data from different sources into a single application. These APIs often use standardized data formats, such as JSON or XML, to ensure compatibility and interoperability between different systems.
#
# As the amount of data available online continues to grow, APIs for retrieving data have become an essential tool for developers to access and analyze this data. By leveraging these APIs, developers can quickly and easily retrieve the data they need, without having to manually extract and process it themselves.

# %% [markdown]
# ### API types
# There are several types of APIs available, but two of the most commonly used types are REST API and HTTP API.
#
# - REST API (Representational State Transfer API):
# REST stands for Representational State Transfer, and it's a set of architectural principles for building web services. A REST API is a type of web service that follows the REST architecture principles. REST APIs use HTTP methods (GET, POST, PUT, DELETE, etc.) to access and manipulate resources, which are identified by URIs (Uniform Resource Identifiers). REST APIs typically return data in JSON or XML format and are widely used for building web and mobile applications.
#
#
# - HTTP API (Hypertext Transfer Protocol API):
# HTTP stands for Hypertext Transfer Protocol, which is the protocol used for transferring data over the World Wide Web. An HTTP API is a type of web service that uses HTTP methods to access and manipulate resources. An HTTP API can be RESTful, but it doesn't have to be. HTTP APIs are often used for simple operations like CRUD (Create, Read, Update, Delete) on resources and return data in JSON or XML format.
#
#
# Other types of APIs include SOAP (Simple Object Access Protocol), GraphQL, and WebSockets. SOAP is an older protocol used for building web services, while GraphQL is a newer API technology that allows clients to specify the data they need and receive it in a single request. WebSockets are used for real-time, two-way communication between a client and a server.

# %% [markdown]
# ### python and APIs

# %% [markdown]
# Python is a popular programming language that provides powerful tools for interacting with APIs. Here are the steps to interact with APIs using Python:
#
# 1. Import the necessary libraries: Python has several libraries that make it easy to interact with APIs, including requests, json, and urllib. Before making any API requests, you need to import the appropriate libraries.
#
# 2. Find the API endpoint: The endpoint is the URL that you will use to send your API requests. It's essential to understand the API documentation to find the correct endpoint for the specific data you want to retrieve.
#
# 3. Send a request: Once you have the endpoint, you can use Python's requests library to send an HTTP request to the API endpoint. The requests library has several methods for sending different types of HTTP requests, including GET, POST, PUT, DELETE, and more.
#
# 4. Parse the response: The API response will typically be in JSON format. Python's json library can be used to parse the JSON data and convert it into a Python dictionary that you can easily work with in your code.
#
# 5. Extract the data: Once you have the API response in a Python dictionary, you can extract the data you need and use it in your application.
#
# Python's ease of use and powerful libraries make it an excellent language for interacting with APIs. With just a few lines of code, you can send requests to APIs, parse the response data, and extract the information you need to build powerful applications.

# %% [markdown]
# ### Using the request package

# %% [markdown]
# To do this, we need to know how to send requests first. We will use an amazing package called [`requests`](http://docs.python-requests.org/en/master/). If you do not have it installed, please install it using e.g. `pip` (in your command prompt or terminal):
#
#
# ```$ pip install requests```

# %%
import requests # library for making HTTP requests
import pandas as pd # library for data analysis
import datetime as dt # library for handling date and time objects
# Out:
# /Users/martinpetribagger/miniconda3/lib/python3.9/site-packages/requests/__init__.py:102: RequestsDependencyWarning: urllib3 (1.26.9) or chardet (5.0.0)/charset_normalizer (2.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({})/charset_normalizer ({}) doesn't match a supported "

# %% [markdown]
# ###### open DMI weather data
#
# Go to the [documentation](https://confluence.govcloud.dk/display/FDAPI/Danish+Meteorological+Institute+-+Open+Data)
#
# Using weather as an example, we should first know what is the request URL (where the request goes to), with what parameters(e.g., API key and stationID). In our case, we know that our API key and the stationId to query so we can do the following.

# %%
api_key = '98ec120f-22ae-4c65-bee5-c7979ce58fe2'
stationId = '06074' # list of stationId: https://confluence.govcloud.dk/pages/viewpage.action?pageId=41717704

# %%
DMI_URL = 'https://dmigw.govcloud.dk/v2/metObs/collections/station/items'
r = requests.get(DMI_URL, params={'api-key': api_key, "stationId": stationId}) # Issues a HTTP GET request
r.url # `requests` help us encode the URL in the correct format
# Out:
# 'https://dmigw.govcloud.dk/v2/metObs/collections/station/items?api-key=98ec120f-22ae-4c65-bee5-c7979ce58fe2&stationId=06074'

# %%
r.status_code # 200 means success
# Out:
# 200

# %%
station = r.json()
station
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'geometry': {'coordinates': [10.1703, 56.1945],
#     'type': 'Point'},
#    'id': '1534ad6f-44ca-722c-02de-222ed7c5873b',
#    'type': 'Feature',
#    'properties': {'barometerHeight': None,
#     'country': 'DNK',
#     'created': '2023-01-24T11:42:06Z',
#     'name': 'Kirstinesminde Flyveplads',
#     'operationFrom': '1976-06-14T00:00:00Z',
#     'operationTo': None,
#     'owner': 'DMI',
#     'parameterId': ['cloud_cover',
#      'cloud_height',
#      'humidity',
#      'humidity_past1h',
#      'precip_dur_past10min',
#      'precip_dur_past1h',
#      'precip_past10min',
#      'precip_past1h',
#      'precip_past24h',
#      'pressure',
#      'pressure_at_sea',
#      'temp_dew',
#      'temp_dry',
#      'temp_max_past12h',
#      'temp_max_past1h',
#      'temp_mean_past1h',
#      'temp_min_past12h',
#      'temp_min_past1h',
#      'visib_mean_last10min',
#      'visibility',
#      'weather',
#      'wind_dir',
#      'wind_dir_past1h',
#      'wind_gust_always_past1h',
#      'wind_max',
#      'wind_max_per10min_past1h',
#      'wind_min',
#      'wind_min_past1h',
#      'wind_speed',
#      'wind_speed_past1h'],
#     'regionId': '6',
#     'stationHeight': None,
#     'stationId': '06074',
#     'status': 'Active',
#     'type': 'Synop',
#     'updated': None,
#     'validFrom': '1976-06-14T00:00:00Z',
#     'validTo': '1987-09-21T00:00:00Z',
#     'wmoCountryCode': '6080',
#     'wmoStationId': '06074'}},
#   {'geometry': {'coordinates': [10.1353, 56.0803], 'type': 'Point'},
#    'id': 'ab5b5587-1c0e-0752-e81c-08a36b6878d6',
#    'type': 'Feature',
#    'properties': {'barometerHeight': None,
#     'country': 'DNK',
#     'created': '2023-01-24T11:42:06Z',
#     'name': 'Århus Syd',
#     'operationFrom': '1976-06-14T00:00:00Z',
#     'operationTo': None,
#     'owner': 'DMI',
#     'parameterId': ['cloud_cover',
#      'cloud_height',
#      'humidity',
#      'humidity_past1h',
#      'precip_dur_past10min',
#      'precip_dur_past1h',
#      'precip_past10min',
#      'precip_past1h',
#      'precip_past24h',
#      'pressure',
#      'pressure_at_sea',
#      'temp_dew',
#      'temp_dry',
#      'temp_max_past12h',
#      'temp_max_past1h',
#      'temp_mean_past1h',
#      'temp_min_past12h',
#      'temp_min_past1h',
#      'visib_mean_last10min',
#      'visibility',
#      'weather',
#      'wind_dir',
#      'wind_dir_past1h',
#      'wind_gust_always_past1h',
#      'wind_max',
#      'wind_max_per10min_past1h',
#      'wind_min',
#      'wind_min_past1h',
#      'wind_speed',
#      'wind_speed_past1h'],
#     'regionId': '6',
#     'stationHeight': 53.82,
#     'stationId': '06074',
#     'status': 'Active',
#     'type': 'Synop',
#     'updated': None,
#     'validFrom': '1987-09-21T00:00:00Z',
#     'validTo': '2019-01-15T13:34:47Z',
#     'wmoCountryCode': '6080',
#     'wmoStationId': '06074'}},
#   {'geometry': {'coordinates': [10.1353, 56.0803], 'type': 'Point'},
#    'id': 'e07ec26d-b226-9305-13dc-605e67cf0bc1',
#    'type': 'Feature',
#    'properties': {'barometerHeight': 55.47,
#     'country': 'DNK',
#     'created': '2023-01-24T11:42:06Z',
#     'name': 'Århus Syd',
#     'operationFrom': '1976-06-14T00:00:00Z',
#     'operationTo': None,
#     'owner': 'DMI',
#     'parameterId': ['cloud_cover',
#      'cloud_height',
#      'humidity',
#      'humidity_past1h',
#      'precip_dur_past10min',
#      'precip_dur_past1h',
#      'precip_past10min',
#      'precip_past1h',
#      'precip_past24h',
#      'pressure',
#      'pressure_at_sea',
#      'temp_dew',
#      'temp_dry',
#      'temp_max_past12h',
#      'temp_max_past1h',
#      'temp_mean_past1h',
#      'temp_min_past12h',
#      'temp_min_past1h',
#      'visib_mean_last10min',
#      'visibility',
#      'weather',
#      'wind_dir',
#      'wind_dir_past1h',
#      'wind_gust_always_past1h',
#      'wind_max',
#      'wind_max_per10min_past1h',
#      'wind_min',
#      'wind_min_past1h',
#      'wind_speed',
#      'wind_speed_past1h'],
#     'regionId': '6',
#     'stationHeight': 53.82,
#     'stationId': '06074',
#     'status': 'Active',
#     'type': 'Synop',
#     'updated': None,
#     'validFrom': '2019-01-15T13:34:47Z',
#     'validTo': None,
#     'wmoCountryCode': '6080',
#     'wmoStationId': '06074'}}],
#  'timeStamp': '2023-03-21T00:25:26Z',
#  'numberReturned': 3,
#  'links': [{'href': 'https://dmigw.govcloud.dk/v2/metObs/collections/station/items?api-key=98ec120f-22ae-4c65-bee5-c7979ce58fe2&stationId=06074',
#    'rel': 'self',
#    'type': 'application/geo+json',
#    'title': 'This document'},
#   {'href': 'https://dmigw.govcloud.dk/v2/metObs/collections/station/items?api-key=98ec120f-22ae-4c65-bee5-c7979ce58fe2&stationId=06074&offset=3',
#    'rel': 'next',
#    'type': 'application/geo+json',
#    'title': 'Next set of results'}]}

# %%
DMI_URL = 'https://dmigw.govcloud.dk/v2/metObs/collections/observation/items'
r = requests.get(DMI_URL, params={'api-key': api_key, "stationId": '06074', 'period': 'latest-day', 'parameterId': 'temp_dry'}) # Issues a HTTP GET request
print(r)
# Out:
# <Response [200]>

# %%
dmi = r.json()  # Extract JSON data
dmi  # Print the keys of the JSON dictionary
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'geometry': {'coordinates': [10.1353, 56.0803],
#     'type': 'Point'},
#    'id': 'a54242fc-e23c-0fed-92b7-abca590358ef',
#    'type': 'Feature',
#    'properties': {'created': '2023-03-21T00:27:31.936680Z',
#     'observed': '2023-03-21T00:30:00Z',
#     'parameterId': 'temp_dry',
#     'stationId': '06074',
#     'value': 1.6}},
#   {'geometry': {'coordinates': [10.1353, 56.0803], 'type': 'Point'},
#    'id': '6ab6989a-308b-5422-197b-a1c19ca54b42',
#    'type': 'Feature',
#    'properties': {'created': '2023-03-21T00:17:24.938092Z',
#     'observed': '2023-03-21T00:20:00Z',
#     'parameterId': 'temp_dry',
#     'stationId': '06074',
#     'value': 1.6}},
#   {'geometry': {'coordinates': [10.1353, 56.0803], 'type': 'Point'},
#    'id': '2a5546ba-cd60-b453-93ca-222dc1390560',
#    'type': 'Feature',
#    'properties': {'created': '2023-03-21T00:07:34.935896Z',
#     'observed': '2023-03-21T00:10:00Z',
#     'parameterId': 'temp_dry',
#     'stationId': '06074',
#     'value': 1.6}},
#   {'geometry': {'coordinates': [10.1353, 56.0803], 'type': 'Point'},
#    'id': '6b7617ef-f93a-60f3-98e1-8e6feb8cce5d',
#    'type': 'Feature',
#    'properties': {'created': '2023-03-20T23:57:53.950806Z',
#     'observed': '2023-03-21T00:00:00Z',
#     'parameterId': 'temp_dry',
#     'stationId': '06074',
#     'value': 1.5}},
#   {'geometry': {'coordinates': [10.1353, 56.0803], 'type': 'Point'},
#    'id': 'c5cfb190-2daa-96d5-1a58-8a32dba41c8e',
#    'type': 'Feature',
#    'properties': {'created': '2023-03-20T23:47:37.438982Z',
#     'observed': '2023-03-20T23:50:00Z',
#     'parameterId': 'temp_dry',
#     'stationId': '06074',
#     'value': 1.4}},
#   {'geometry': {'coordinates': [10.1353, 56.0803], 'type': 'Point'},
#    'id': '9925908e-ff1f-e5dc-6833-d376ced80bf1',
#    'type': 'Feature',
#    'properties': {'created': '2023-03-20T23:37:25.937032Z',
#     'observed': '2023-03-20T23:40:00Z',
#     'parameterId': 'temp_dry',
#     'stationId': '06074',
#     'value': 1.5}},
#   {'geometry': {'coordinates': [10.1353, 56.0803], 'type': 'Point'},
#    'id': '81d332b1-9662-5768-d4a2-7793d99a773f',
#    'type': 'Feature',
#    'properties': {'created': '2023-03-20T23:27:32.436738Z',
#     'observed': '2023-03-20T23:30:00Z',
#     'parameterId': 'temp_dry',
#     'stationId': '06074',
#     'value': 1.7}},
#   {'geometry': {'coordinates': [10.1353, 56.0803], 'type': 'Point'},
#    'id': '36452dcd-7bb1-4b2b-54d4-8941d5d99123',
#    'type': 'Feature',
#    'properties': {'created': '2023-03-20T23:17:27.937838Z',
#     'observed': '2023-03-20T23:20:00Z',
#     'parameterId': 'temp_dry',
#     'stationId': '06074',
#     'value': 1.6}},
#   {'geometry': {'coordinates': [10.1353, 56.0803], 'type': 'Point'},
#    'id': 'ed00d2a1-78bf-9dfa-9911-3b8f210ee429',
#    'type': 'Feature',
#    'properties': {'created': '2023-03-20T23:07:36.936861Z',
#     'observed': '2023-03-20T23:10:00Z',
#     'parameterId': 'temp_dry',
#     'stationId': '06074',
#     'value': 1.8}},
#   {'geometry': {'coordinates': [10.1353, 56.0803], 'type': 'Point'},
#    'id': 'b62d64bb-6457-753c-022f-73b910c897e5',
#    'type': 'Feature',
#    'properties': {'created': '2023-03-20T22:57:38.439131Z',
#     'observed': '2023-03-20T23:00:00Z',
#     'parameterId': 'temp_dry',
#     'stationId': '06074',
#     'value': 1.9}},
#   {'geometry': {'coordinates': [10.1353, 56.0803], 'type': 'Point'},
#    'id': '19450de5-4fcd-d1f1-1471-ba8bcd8be596',
#    'type': 'Feature',
#    'properties': {'created': '2023-03-20T22:47:27.937491Z',
#     'observed': '2023-03-20T22:50:00Z',
#     'parameterId': 'temp_dry',
#     'stationId': '06074',
#     'value': 1.8}},
#   {'geometry': {'coordinates': [10.1353, 56.0803], 'type': 'Point'},
#    'id': 'dc117988-fa4b-d486-41a8-c2d1d3c2cbc0',
#    'type': 'Feature',
#    'properties': {'created': '2023-03-20T22:37:24.937359Z',
#     'observed': '2023-03-20T22:40:00Z',
#     'parameterId': 'temp_dry',
#     'stationId': '06074',
#     'value': 1.8}},
#   {'geometry': {'coordinates': [10.1353, 56.0803], 'type': 'Point'},
#    'id': '49f3c802-0186-063a-cf51-e920ea0d5dff',
#    'type': 'Feature',
#    'properties': {'created': '2023-03-20T22:27:22.935172Z',
#     'observed': '2023-03-20T22:30:00Z',
#     'parameterId': 'temp_dry',
#     'stationId': '06074',
#     'value': 1.9}},
#   {'geometry': {'coordinates': [10.1353, 56.0803], 'type': 'Point'},
#    'id': '370ae490-9074-67b1-9af3-feaf48d53126',
#    'type': 'Feature',
#    'properties': {'created': '2023-03-20T22:17:33.938137Z',
#     'observed': '2023-03-20T22:20:00Z',
#     'parameterId': 'temp_dry',
#     'stationId': '06074',
#     'value': 1.4}},
#   {'geometry': {'coordinates': [10.1353, 56.0803], 'type': 'Point'},
#    'id': '906961ea-d377-ed54-cd7e-aba8969be904',
#    'type': 'Feature',
#    'properties': {'created': '2023-03-20T22:07:40.438026Z',
#     'observed': '2023-03-20T22:10:00Z',
#     'parameterId': 'temp_dry',
#     'stationId': '06074',
#     'value': 1.2}},
#   {'geometry': {'coordinates': [10.1353, 56.0803], 'type': 'Point'},
#    'id': '6f45ebab-097e-b5a9-0f58-5daea440d2af',
#    'type': 'Feature',
#    'properties': {'created': '2023-03-20T21:57:36.935454Z',
#     'observed': '2023-03-20T22:00:00Z',
#     'parameterId': 'temp_dry',
#     'stationId': '06074',
#     'value': 1.3}},
#   {'geometry': {'coordinates': [10.1353, 56.0803], 'type': 'Point'},
#    'id': 'abff866d-afef-b7b4-d351-fc9ce9b892b8',
#    'type': 'Feature',
#    'properties': {'created': '2023-03-20T21:47:23.435888Z',
#     'observed': '2023-03-20T21:50:00Z',
#     'parameterId': 'temp_dry',
#     'stationId': '06074',
#     'value': 1.0}},
#   {'geometry': {'coordinates': [10.1353, 56.0803], 'type': 'Point'},
#    'id': '43c6061d-5d13-9664-b525-ec3fc3ca70fc',
#    'type': 'Feature',
#    'properties': {'created': '2023-03-20T21:37:22.436128Z',
#     'observed': '2023-03-20T21:40:00Z',
#     'parameterId': 'temp_dry',
#     'stationId': '06074',
#     'value': 1.7}},
#   {'geometry': {'coordinates': [10.1353, 56.0803], 'type': 'Point'},
#    'id': 'f8a42819-5ecc-82a8-c8a9-e959a7b4a1ea',
#    'type': 'Feature',
#    'properties': {'created': '2023-03-20T21:27:29.442997Z',
#     'observed': '2023-03-20T21:30:00Z',
#     'parameterId': 'temp_dry',
#     'stationId': '06074',
#     'value': 2.1}},
#   {'geometry': {'coordinates': [10.1353, 56.0803], 'type': 'Point'},
#    'id': '88e8cb4e-ca33-c17e-1a13-035ef992b88a',
#    'type': 'Feature',
#    'properties': {'created': '2023-03-20T21:17:54.940311Z',
#     'observed': '2023-03-20T21:20:00Z',
#     'parameterId': 'temp_dry',
#     'stationId': '06074',
#     'value': 2.4}},
#   {'geometry': {'coordinates': [10.1353, 56.0803], 'type': 'Point'},
#    'id': '7609090d-b616-f18d-127a-586c6adeed6a',
#    'type': 'Feature',
#    'properties': {'created': '2023-03-20T21:07:32.441582Z',
#     'observed': '2023-03-20T21:10:00Z',
#     'parameterId': 'temp_dry',
#     'stationId': '06074',
#     'value': 2.5}},
#   {'geometry': {'coordinates': [10.1353, 56.0803], 'type': 'Point'},
#    'id': 'f25e30ba-5e8e-a29a-369b-f003a29b06b7',
#    'type': 'Feature',
#    'properties': {'created': '2023-03-20T20:57:38.940138Z',
#     'observed': '2023-03-20T21:00:00Z',
#     'parameterId': 'temp_dry',
#     'stationId': '06074',
#     'value': 2.6}},
#   {'geometry': {'coordinates': [10.1353, 56.0803], 'type': 'Point'},
#    'id': '0497b9d7-0b06-017e-a76d-2f461b6c41bf',
#    'type': 'Feature',
#    'properties': {'created': '2023-03-20T20:47:21.936889Z',
#     'observed': '2023-03-20T20:50:00Z',
#     'parameterId': 'temp_dry',
#     'stationId': '06074',
#     'value': 1.9}},
#   {'geometry': {'coordinates': [10.1353, 56.0803], 'type': 'Point'},
#    'id': 'ffd992b2-6d0d-2d3c-a454-cb13f48e3981',
#    'type': 'Feature',
#    'properties': {'created': '2023-03-20T20
10:00Z',
#     'parameterId': 'temp_dry',
#     'stationId': '06074',
#     'value': 6.0}},
#   {'geometry': {'coordinates': [10.1353, 56.0803], 'type': 'Point'},
#    'id': 'ebffa6f0-8078-b64c-c588-599485b17812',
#    'type': 'Feature',
#    'properties': {'created': '2023-03-20T02:57:43.936657Z',
#     'observed': '2023-03-20T03:00:00Z',
#     'parameterId': 'temp_dry',
#     'stationId': '06074',
#     'value': 6.0}},
#   {'geometry': {'coordinates': [10.1353, 56.0803], 'type': 'Point'},
#    'id': 'e36a7b59-a115-e725-41b1-1a56bd3a1e66',
#    'type': 'Feature',
#    'properties': {'created': '2023-03-20T02:47:45.941714Z',
#     'observed': '2023-03-20T02:50:00Z',
#     'parameterId': 'temp_dry',
#     'stationId': '06074',
#     'value': 6.1}},
#   {'geometry': {'coordinates': [10.1353, 56.0803], 'type': 'Point'},
#    'id': 'b0c26c11-1a20-15ad-c3b6-51e09afde87f',
#    'type': 'Feature',
#    'properties': {'created': '2023-03-20T02:37:36.448387Z',
#     'observed': '2023-03-20T02:40:00Z',
#     'parameterId': 'temp_dry',
#     'stationId': '06074',
#     'value': 6.0}},
#   {'geometry': {'coordinates': [10.1353, 56.0803], 'type': 'Point'},
#    'id': '5efd44a4-9b9a-1da1-59f0-9e248fbcef44',
#    'type': 'Feature',
#    'properties': {'created': '2023-03-20T02:27:33.939614Z',
#     'observed': '2023-03-20T02:30:00Z',
#     'parameterId': 'temp_dry',
#     'stationId': '06074',
#     'value': 6.0}},
#   {'geometry': {'coordinates': [10.1353, 56.0803], 'type': 'Point'},
#    'id': 'e88034b6-3446-8d5b-bbee-d4327b37c523',
#    'type': 'Feature',
#    'properties': {'created': '2023-03-20T02:17:32.449745Z',
#     'observed': '2023-03-20T02:20:00Z',
#     'parameterId': 'temp_dry',
#     'stationId': '06074',
#     'value': 6.1}},
#   {'geometry': {'coordinates': [10.1353, 56.0803], 'type': 'Point'},
#    'id': '11a65337-53f3-bb76-e019-be161b1e070a',
#    'type': 'Feature',
#    'properties': {'created': '2023-03-20T02:07:33.435202Z',
#     'observed': '2023-03-20T02:10:00Z',
#     'parameterId': 'temp_dry',
#     'stationId': '06074',
#     'value': 6.0}},
#   {'geometry': {'coordinates': [10.1353, 56.0803], 'type': 'Point'},
#    'id': 'cddceecb-36ec-da97-c4c4-4793215645a9',
#    'type': 'Feature',
#    'properties': {'created': '2023-03-20T01:57:32.942146Z',
#     'observed': '2023-03-20T02:00:00Z',
#     'parameterId': 'temp_dry',
#     'stationId': '06074',
#     'value': 6.1}},
#   {'geometry': {'coordinates': [10.1353, 56.0803], 'type': 'Point'},
#    'id': 'db0000a0-3a61-bc6d-28b4-cebb23af8d46',
#    'type': 'Feature',
#    'properties': {'created': '2023-03-20T01:47:33.942435Z',
#     'observed': '2023-03-20T01:50:00Z',
#     'parameterId': 'temp_dry',
#     'stationId': '06074',
#     'value': 6.1}},
#   {'geometry': {'coordinates': [10.1353, 56.0803], 'type': 'Point'},
#    'id': '6691464d-b063-8fef-d67e-c487d375c8dd',
#    'type': 'Feature',
#    'properties': {'created': '2023-03-20T01:37:28.475073Z',
#     'observed': '2023-03-20T01:40:00Z',
#     'parameterId': 'temp_dry',
#     'stationId': '06074',
#     'value': 6.2}},
#   {'geometry': {'coordinates': [10.1353, 56.0803], 'type': 'Point'},
#    'id': '6fbcb040-6bb0-c300-b06a-80762df8cf6e',
#    'type': 'Feature',
#    'properties': {'created': '2023-03-20T01:27:33.945015Z',
#     'observed': '2023-03-20T01:30:00Z',
#     'parameterId': 'temp_dry',
#     'stationId': '06074',
#     'value': 6.1}},
#   {'geometry': {'coordinates': [10.1353, 56.0803], 'type': 'Point'},
#    'id': 'c0818ca6-2a39-27e6-3eab-cfd640ae4b06',
#    'type': 'Feature',
#    'properties': {'created': '2023-03-20T01:17:58.937794Z',
#     'observed': '2023-03-20T01:20:00Z',
#     'parameterId': 'temp_dry',
#     'stationId': '06074',
#     'value': 6.1}},
#   {'geometry': {'coordinates': [10.1353, 56.0803], 'type': 'Point'},
#    'id': 'de214a6c-116a-1373-6341-14da67e6b5c5',
#    'type': 'Feature',
#    'properties': {'created': '2023-03-20T01:07:34.935369Z',
#     'observed': '2023-03-20T01:10:00Z',
#     'parameterId': 'temp_dry',
#     'stationId': '06074',
#     'value': 6.3}},
#   {'geometry': {'coordinates': [10.1353, 56.0803], 'type': 'Point'},
#    'id': '79a8d409-a7d2-6254-f9a3-213c88b9bb94',
#    'type': 'Feature',
#    'properties': {'created': '2023-03-20T00:57:33.439189Z',
#     'observed': '2023-03-20T01:00:00Z',
#     'parameterId': 'temp_dry',
#     'stationId': '06074',
#     'value': 6.2}},
#   {'geometry': {'coordinates': [10.1353, 56.0803], 'type': 'Point'},
#    'id': 'ac82087b-5e34-1b85-c06b-cf8048311042',
#    'type': 'Feature',
#    'properties': {'created': '2023-03-20T00:47:36.436788Z',
#     'observed': '2023-03-20T00:50:00Z',
#     'parameterId': 'temp_dry',
#     'stationId': '06074',
#     'value': 6.3}},
#   {'geometry': {'coordinates': [10.1353, 56.0803], 'type': 'Point'},
#    'id': '1cf616ab-76a5-f021-7317-98f8621e722f',
#    'type': 'Feature',
#    'properties': {'created': '2023-03-20T00:37:41.440792Z',
#     'observed': '2023-03-20T00:40:00Z',
#     'parameterId': 'temp_dry',
#     'stationId': '06074',
#     'value': 6.3}}],
#  'timeStamp': '2023-03-21T00:39:27Z',
#  'numberReturned': 144,
#  'links': [{'href': 'https://dmigw.govcloud.dk/v2/metObs/collections/observation/items?api-key=98ec120f-22ae-4c65-bee5-c7979ce58fe2&stationId=06074&period=latest-day&parameterId=temp_dry',
#    'rel': 'self',
#    'type': 'application/geo+json',
#    'title': 'This document'},
#   {'href': 'https://dmigw.govcloud.dk/v2/metObs/collections/observation/items?api-key=98ec120f-22ae-4c65-bee5-c7979ce58fe2&stationId=06074&period=latest-day&parameterId=temp_dry&offset=144',
#    'rel': 'next',
#    'type': 'application/geo+json',
#    'title': 'Next set of results'}]}

# %% [markdown]
# JSON object will be converted into a `dict` type, which is the data structure in Python holding key value pairs. To access certain values, we just access them like a `dict`.

# %%
dmi['features']
# Out:
# [{'geometry': {'coordinates': [10.1353, 56.0803], 'type': 'Point'},
#   'id': 'a54242fc-e23c-0fed-92b7-abca590358ef',
#   'type': 'Feature',
#   'properties': {'created': '2023-03-21T00:27:31.936680Z',
#    'observed': '2023-03-21T00:30:00Z',
#    'parameterId': 'temp_dry',
#    'stationId': '06074',
#    'value': 1.6}},
#  {'geometry': {'coordinates': [10.1353, 56.0803], 'type': 'Point'},
#   'id': '6ab6989a-308b-5422-197b-a1c19ca54b42',
#   'type': 'Feature',
#   'properties': {'created': '2023-03-21T00:17:24.938092Z',
#    'observed': '2023-03-21T00:20:00Z',
#    'parameterId': 'temp_dry',
#    'stationId': '06074',
#    'value': 1.6}},
#  {'geometry': {'coordinates': [10.1353, 56.0803], 'type': 'Point'},
#   'id': '2a5546ba-cd60-b453-93ca-222dc1390560',
#   'type': 'Feature',
#   'properties': {'created': '2023-03-21T00:07:34.935896Z',
#    'observed': '2023-03-21T00:10:00Z',
#    'parameterId': 'temp_dry',
#    'stationId': '06074',
#    'value': 1.6}},
#  {'geometry': {'coordinates': [10.1353, 56.0803], 'type': 'Point'},
#   'id': '6b7617ef-f93a-60f3-98e1-8e6feb8cce5d',
#   'type': 'Feature',
#   'properties': {'created': '2023-03-20T23

#   'type': 'Feature',
#   'properties': {'created': '2023-03-20T01:57:32.942146Z',
#    'observed': '2023-03-20T02:00:00Z',
#    'parameterId': 'temp_dry',
#    'stationId': '06074',
#    'value': 6.1}},
#  {'geometry': {'coordinates': [10.1353, 56.0803], 'type': 'Point'},
#   'id': 'db0000a0-3a61-bc6d-28b4-cebb23af8d46',
#   'type': 'Feature',
#   'properties': {'created': '2023-03-20T01:47:33.942435Z',
#    'observed': '2023-03-20T01:50:00Z',
#    'parameterId': 'temp_dry',
#    'stationId': '06074',
#    'value': 6.1}},
#  {'geometry': {'coordinates': [10.1353, 56.0803], 'type': 'Point'},
#   'id': '6691464d-b063-8fef-d67e-c487d375c8dd',
#   'type': 'Feature',
#   'properties': {'created': '2023-03-20T01:37:28.475073Z',
#    'observed': '2023-03-20T01:40:00Z',
#    'parameterId': 'temp_dry',
#    'stationId': '06074',
#    'value': 6.2}},
#  {'geometry': {'coordinates': [10.1353, 56.0803], 'type': 'Point'},
#   'id': '6fbcb040-6bb0-c300-b06a-80762df8cf6e',
#   'type': 'Feature',
#   'properties': {'created': '2023-03-20T01:27:33.945015Z',
#    'observed': '2023-03-20T01:30:00Z',
#    'parameterId': 'temp_dry',
#    'stationId': '06074',
#    'value': 6.1}},
#  {'geometry': {'coordinates': [10.1353, 56.0803], 'type': 'Point'},
#   'id': 'c0818ca6-2a39-27e6-3eab-cfd640ae4b06',
#   'type': 'Feature',
#   'properties': {'created': '2023-03-20T01:17:58.937794Z',
#    'observed': '2023-03-20T01:20:00Z',
#    'parameterId': 'temp_dry',
#    'stationId': '06074',
#    'value': 6.1}},
#  {'geometry': {'coordinates': [10.1353, 56.0803], 'type': 'Point'},
#   'id': 'de214a6c-116a-1373-6341-14da67e6b5c5',
#   'type': 'Feature',
#   'properties': {'created': '2023-03-20T01:07:34.935369Z',
#    'observed': '2023-03-20T01:10:00Z',
#    'parameterId': 'temp_dry',
#    'stationId': '06074',
#    'value': 6.3}},
#  {'geometry': {'coordinates': [10.1353, 56.0803], 'type': 'Point'},
#   'id': '79a8d409-a7d2-6254-f9a3-213c88b9bb94',
#   'type': 'Feature',
#   'properties': {'created': '2023-03-20T00:57:33.439189Z',
#    'observed': '2023-03-20T01:00:00Z',
#    'parameterId': 'temp_dry',
#    'stationId': '06074',
#    'value': 6.2}},
#  {'geometry': {'coordinates': [10.1353, 56.0803], 'type': 'Point'},
#   'id': 'ac82087b-5e34-1b85-c06b-cf8048311042',
#   'type': 'Feature',
#   'properties': {'created': '2023-03-20T00:47:36.436788Z',
#    'observed': '2023-03-20T00:50:00Z',
#    'parameterId': 'temp_dry',
#    'stationId': '06074',
#    'value': 6.3}},
#  {'geometry': {'coordinates': [10.1353, 56.0803], 'type': 'Point'},
#   'id': '1cf616ab-76a5-f021-7317-98f8621e722f',
#   'type': 'Feature',
#   'properties': {'created': '2023-03-20T00:37:41.440792Z',
#    'observed': '2023-03-20T00:40:00Z',
#    'parameterId': 'temp_dry',
#    'stationId': '06074',
#    'value': 6.3}}]

# %%
dmi['features'][0]
# Out:
# {'geometry': {'coordinates': [10.1353, 56.0803], 'type': 'Point'},
#  'id': 'a6d44423-c73d-a0c7-e07b-0128129a8793',
#  'type': 'Feature',
#  'properties': {'created': '2023-03-21T00:27:31.947575Z',
#   'observed': '2023-03-21T00:30:00Z',
#   'parameterId': 'visibility',
#   'stationId': '06074',
#   'value': 200.0}}

# %%
dmi['features'][0]['properties']
# Out:
# {'created': '2023-03-21T00:27:31.947575Z',
#  'observed': '2023-03-21T00:30:00Z',
#  'parameterId': 'visibility',
#  'stationId': '06074',
#  'value': 200.0}

# %%
dmi['features'][0]['properties']['value']
# Out:
# 200.0

# %%
for feature in dmi['features']:
    for key, value in feature['properties'].items():
         print(key, value)
# Out:
# created 2023-03-21T00:17:24.938092Z
# observed 2023-03-21T00:20:00Z
# parameterId temp_dry
# stationId 06074
# value 1.6
# created 2023-03-21T00:17:24.938092Z
# observed 2023-03-21T00:20:00Z
# parameterId temp_dry
# stationId 06074
# value 1.6
# created 2023-03-21T00:07:34.935896Z
# observed 2023-03-21T00:10:00Z
# parameterId temp_dry
# stationId 06074
# value 1.6
# created 2023-03-20T23:57:53.950806Z
# observed 2023-03-21T00:00:00Z
# parameterId temp_dry
# stationId 06074
# value 1.5
# created 2023-03-20T23:47:37.438982Z
# observed 2023-03-20T23:50:00Z
# parameterId temp_dry
# stationId 06074
# value 1.4
# created 2023-03-20T23:37:25.937032Z
# observed 2023-03-20T23:40:00Z
# parameterId temp_dry
# stationId 06074
# value 1.5
# created 2023-03-20T23:27:32.436738Z
# observed 2023-03-20T23:30:00Z
# parameterId temp_dry
# stationId 06074
# value 1.7
# created 2023-03-20T23:17:27.937838Z
# observed 2023-03-20T23:20:00Z
# parameterId temp_dry
# stationId 06074
# value 1.6
# created 2023-03-20T23:07:36.936861Z
00Z
# parameterId temp_dry
# stationId 06074
# value 5.9
# created 2023-03-20T04:47:33.435319Z
# observed 2023-03-20T04:50:00Z
# parameterId temp_dry
# stationId 06074
# value 5.8
# created 2023-03-20T04:37:37.444438Z
# observed 2023-03-20T04:40:00Z
# parameterId temp_dry
# stationId 06074
# value 5.9
# created 2023-03-20T04:27:37.435570Z
# observed 2023-03-20T04:30:00Z
# parameterId temp_dry
# stationId 06074
# value 6.1
# created 2023-03-20T04:17:34.438408Z
# observed 2023-03-20T04:20:00Z
# parameterId temp_dry
# stationId 06074
# value 5.9
# created 2023-03-20T04:07:33.439138Z
# observed 2023-03-20T04:10:00Z
# parameterId temp_dry
# stationId 06074
# value 6.1
# created 2023-03-20T03:57:47.437369Z
# observed 2023-03-20T04:00:00Z
# parameterId temp_dry
# stationId 06074
# value 6.1
# created 2023-03-20T03:47:28.969876Z
# observed 2023-03-20T03:50:00Z
# parameterId temp_dry
# stationId 06074
# value 6.1
# created 2023-03-20T03:37:35.445452Z
# observed 2023-03-20T03:40:00Z
# parameterId temp_dry
# stationId 06074
# value 5.9
# created 2023-03-20T03:27:32.435721Z
# observed 2023-03-20T03:30:00Z
# parameterId temp_dry
# stationId 06074
# value 6.0
# created 2023-03-20T03:17:35.438583Z
# observed 2023-03-20T03:20:00Z
# parameterId temp_dry
# stationId 06074
# value 6.0
# created 2023-03-20T03:07:37.436057Z
# observed 2023-03-20T03:10:00Z
# parameterId temp_dry
# stationId 06074
# value 6.0
# created 2023-03-20T02:57:43.936657Z
# observed 2023-03-20T03:00:00Z
# parameterId temp_dry
# stationId 06074
# value 6.0
# created 2023-03-20T02:47:45.941714Z
# observed 2023-03-20T02:50:00Z
# parameterId temp_dry
# stationId 06074
# value 6.1
# created 2023-03-20T02:37:36.448387Z
# observed 2023-03-20T02:40:00Z
# parameterId temp_dry
# stationId 06074
# value 6.0
# created 2023-03-20T02:27:33.939614Z
# observed 2023-03-20T02:30:00Z
# parameterId temp_dry
# stationId 06074
# value 6.0
# created 2023-03-20T02:17:32.449745Z
# observed 2023-03-20T02:20:00Z
# parameterId temp_dry
# stationId 06074
# value 6.1
# created 2023-03-20T02:07:33.435202Z
# observed 2023-03-20T02:10:00Z
# parameterId temp_dry
# stationId 06074
# value 6.0
# created 2023-03-20T01:57:32.942146Z
# observed 2023-03-20T02:00:00Z
# parameterId temp_dry
# stationId 06074
# value 6.1
# created 2023-03-20T01:47:33.942435Z
# observed 2023-03-20T01:50:00Z
# parameterId temp_dry
# stationId 06074
# value 6.1
# created 2023-03-20T01:37:28.475073Z
# observed 2023-03-20T01:40:00Z
# parameterId temp_dry
# stationId 06074
# value 6.2
# created 2023-03-20T01:27:33.945015Z
# observed 2023-03-20T01:30:00Z
# parameterId temp_dry
# stationId 06074
# value 6.1
# created 2023-03-20T01:17:58.937794Z
# observed 2023-03-20T01:20:00Z
# parameterId temp_dry
# stationId 06074
# value 6.1
# created 2023-03-20T01:07:34.935369Z
# observed 2023-03-20T01:10:00Z
# parameterId temp_dry
# stationId 06074
# value 6.3
# created 2023-03-20T00:57:33.439189Z
# observed 2023-03-20T01:00:00Z
# parameterId temp_dry
# stationId 06074
# value 6.2
# created 2023-03-20T00:47:36.436788Z
# observed 2023-03-20T00:50:00Z
# parameterId temp_dry
# stationId 06074
# value 6.3
# created 2023-03-20T00:37:41.440792Z
# observed 2023-03-20T00:40:00Z
# parameterId temp_dry
# stationId 06074
# value 6.3

# %% [markdown]
# Now it gets interesting, as we can put the values into a dataframe (more on dataframes later).

# %%
import pandas as pd

lst = []

for values in dmi['features']:
    lst.append(pd.DataFrame.from_dict(values['properties'], orient='index').transpose())

# %%
df = pd.concat(lst).reset_index()

# %%
df
# Out:
#      index                      created              observed parameterId  \
# 0        0  2023-03-21T00:17:24.938092Z  2023-03-21T00:20:00Z    temp_dry
# 1        0  2023-03-21T00:17:24.938092Z  2023-03-21T00:20:00Z    temp_dry
# 2        0  2023-03-21T00:07:34.935896Z  2023-03-21T00:10:00Z    temp_dry
# 3        0  2023-03-20T23:57:53.950806Z  2023-03-21T00:00:00Z    temp_dry
# 4        0  2023-03-20T23:47:37.438982Z  2023-03-20T23:50:00Z    temp_dry
# ..     ...                          ...                   ...         ...
# 139      0  2023-03-20T01:17:58.937794Z  2023-03-20T01:20:00Z    temp_dry
# 140      0  2023-03-20T01:07:34.935369Z  2023-03-20T01:10:00Z    temp_dry
# 141      0  2023-03-20T00:57:33.439189Z  2023-03-20T01:00:00Z    temp_dry
# 142      0  2023-03-20T00:47:36.436788Z  2023-03-20T00:50:00Z    temp_dry
# 143      0  2023-03-20T00:37:41.440792Z  2023-03-20T00:40:00Z    temp_dry
#
#     stationId value
# 0       06074   1.6
# 1       06074   1.6
# 2       06074   1.6
# 3       06074   1.5
# 4       06074   1.4
# ..        ...   ...
# 139     06074   6.1
# 140     06074   6.3
# 141     06074   6.2
# 142     06074   6.3
# 143     06074   6.3
#
# [144 rows x 6 columns]

# %% [markdown]
# ### Use packages: Twitter API as an example

# %% [markdown]
# Many web servers have their own APIs ready to use. By using these convenient tools, we can get started right off following their documentations and examples without any manual efforts.
#
# We will be using <a href="https://apps.twitter.com/" target="_blank">Twitter API</a> as an example. We will first install this package as shown [here](https://python-twitter.readthedocs.io/en/latest/installation.html)

# %% [markdown]
# You have to register an account for Twitter Developer and register an app.
#
# - go to https://dev.twitter.com/ and get an app togther. <a href="https://python-twitter.readthedocs.io/en/latest/getting_started.html" target="_b lank">Here</a>'s a quick start on how you can do this.
#
# After obtaining *__consumer key__*, *__consumer secret__*, *__access token__*, and *__access token secret__*, you are ready to retrieve some data from Twitter!

# %% [markdown]
# I have created a .env file in my root folder in the following way:
#
# ```
# consumer_key = your_consumer_key
# consumer_secret = your_consumer_secret
# access_token = your_access_token
# access_secret = your_access_secret
# ```

# %%
# Read the keys and tokens into a dictionary
my_dict = {}

with open("../.env", "r") as f:
    for line in f:
        key,val = line.split('=')
        my_dict[key.strip()] = val.strip()

# %%
my_dict
# Out:
# {'api_key': '98ec120f-22ae-4c65-bee5-c7979ce58fe2',
#  'consumer_key': 'pxckjDmamJ3MFSB4zbfGsf81X',
#  'consumer_secret': 'C0c16vwne2UjhcNCW7gv0h2NfqpTDOG4IkYFc8ccpvTyjg6fRv',
#  'access_token': '966273572015624192-VUvEJelTQGTYQijFRJhvbPqz6IqVlLK',
#  'access_secret': 'GCjsYL7lfj54tedcnznjQMJmJv6WNo86t20h4QPK29f37'}

# %%
## load twitter package, which a well-written Python package for Twitter APIs
import twitter
api = twitter.Api(consumer_key=my_dict['consumer_key'],
                  consumer_secret=my_dict['consumer_secret'],                  
                  access_token_key=my_dict['access_token'],
                  access_token_secret=my_dict['access_secret'])

## check status
api.VerifyCredentials()
# Out:
# User(ID=966273572015624192, ScreenName=PetriBagger)

# %%
statuses = api.GetUserTimeline(screen_name="PetriBagger")
for s in statuses:
    print(s.text)
# Out:
# @BornsVilkar @trygfonden @sanne_lind @politiken Det er en temmelig frisk konklusion at smide ud i offentligheden ud… https://t.co/HlVxJuvuWg
# #kapacity testing Azure logic apps
# RT @JosephineFock: Stop den overvågning, helt uacceptabelt at vi fortsat overvåger os alle #dkpol #stoplogning https://t.co/aIFu18Y8hj
# Jeg håber flere vil ty til civil ulydighed og boykotte de nationale trivselsmålinger af vores børn. Det er forrykt… https://t.co/GAf4zIJIvF

# %%
statuses = api.GetUserTimeline(user_id="966273572015624192")
for s in statuses:
    print(s.created_at)
# Out:
# Tue May 05 18:12:25 +0000 2020
# Thu Oct 25 07:24:33 +0000 2018
# Sun Mar 18 20:51:56 +0000 2018
# Mon Mar 12 21:52:22 +0000 2018

# %%
friends = api.GetFriends()
for f in friends:
    print(f.name)
# Out:
# Jakob Sorgenfri Kjær
# SpeakerAllan
# AllanGravgaardMadsen
# Jeppe Søe
# Erik Lahm
# Nielbo
# Astrid Porsmose
# Thor Hampus Bank
# Kirsten Birgit
# Søren Bo Steendahl
# Carl Johannes Borris
# Morten H.J. Fenger
# Martin Ibsen

# %% [markdown]
# More interestingly, let's go get some tweets from Twitter. Let's try to search for tweets related to `gpt4` since 01/01/2023 in English.
# - See https://dev.twitter.com/rest/public/search for more informaiton on how to construct a query

# %%
results = api.GetSearch(
    raw_query="q=gpt4&src=typed_query&before=2023-01-01&lang=en")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 results = api.GetSearch(
#       2     raw_query="q=gpt4&src=typed_query&before=2023-01-01&lang=en")
#
# AttributeError: 'API' object has no attribute 'GetSearch'

# %%
len(results)
# Out:
# 15

# %%
from IPython.display import clear_output
for tw in results:
    print("%s. Tweeted by \033[41m%s\033[0m"%(tw.text, tw.user.screen_name))
# Out:
# @ChatGPTBot #gpt4   whats the news. Tweeted by AliakLeila
# RT @itsaboy560: Just aped 3 eth in #GPT-4 and now it is doubled!! 📈📈📈
#
# 👉https://t.co/mJ5d4GXgx2
#
#   #airdrop #NFT #Crypto $APE $MATIC $MAKI…. Tweeted by alleeahkrishnah
# RT @itsaboy560: Just aped 3 eth in #GPT-4 and now it is doubled!! 📈📈📈
#
# 👉https://t.co/mJ5d4GXgx2
#
#   #airdrop #NFT #Crypto $APE $MATIC $MAKI…. Tweeted by BelloGazpar
# RT @itsaboy560: Just aped 3 eth in #GPT-4 and now it is doubled!! 📈📈📈
#
# 👉https://t.co/mJ5d4GXgx2
#
#   #airdrop #NFT #Crypto $APE $MATIC $MAKI…. Tweeted by _2_2_0_
# RT @itsaboy560: Just aped 3 eth in #GPT-4 and now it is doubled!! 📈📈📈
#
# 👉https://t.co/mJ5d4GXgx2
#
#   #airdrop #NFT #Crypto $APE $MATIC $MAKI…. Tweeted by _10969shochan
# RT @itsaboy560: Just aped 3 eth in #GPT-4 and now it is doubled!! 📈📈📈
#
# 👉https://t.co/mJ5d4GXgx2
#
#   #airdrop #NFT #Crypto $APE $MATIC $MAKI…. Tweeted by biebsbabeh
# RT @itsaboy560: Just aped 3 eth in #GPT-4 and now it is doubled!! 📈📈📈
#
# 👉https://t.co/mJ5d4GXgx2
#
#   #airdrop #NFT #Crypto $APE $MATIC $MAKI…. Tweeted by ___hyphen___
# RT @UseInteraxAI: Just added the ability to add new elements. Watch a video of our fully customizable AI/GPT widgets.
#
# #openai #GPT #ChatGP…. Tweeted by Steb_01
# Just added the ability to add new elements. Watch a video of our fully customizable AI/GPT widgets.
#
# #openai #GPT… https://t.co/ebhLecPJmo. Tweeted by UseInteraxAI
# RT @DataChaz: #GPT4: Make me a website that converts videos into ASCII.
#
# Copy.
# Paste.
# Done! 🙌 https://t.co/4D5iPTu69f. Tweeted by untalpablodz
# Just published “AI Jobs Unveiled with ChatGPT-4 Prompt”
#
# https://t.co/i9cNvIJEC9
#
# #EmergingCareers… https://t.co/n68OZQPoR3. Tweeted by BlackMetaverse
# Using the Chat GPT A.I. to make Eminem rap about cooking steak😂 https://t.co/nxvLFpxnpK via @YouTube
#
# #chatgpt4… https://t.co/H5L97fRNU8. Tweeted by Ultra_Maths
# RT @boazbaraktcs: Another jailbreak for GPT4: Talk to it in Morse code https://t.co/emNierdIXW. Tweeted by cfcosta_
# RT @FA175: What is the hottest topic today? #GPT-4 !!! $GPT-4 is the real deal! 🤑🚀🌕
#
# 👉https://t.co/hhdWlETVnq
#
#   #airdrop #NFT #GPT4 $UNI…. Tweeted by ssk_probrain89
# RT @jacobi_torsten: Wanna take a virtual round the world trip to the most stunning locations without ever leaving the house? Let AI help yo…. Tweeted by soranekokr

# %% [markdown]
# I went through some examples of using APIs to get various types of data in Python. The last Twitter example is relatively superficial. There are other packages to twitter, [`tweepy`] package seems to be pretty popular as well: http://www.tweepy.org/

# %% [markdown]
# return to [overview](../00_overview.ipynb)
